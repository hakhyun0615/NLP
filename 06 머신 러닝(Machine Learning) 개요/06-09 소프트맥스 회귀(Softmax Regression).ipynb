# %% [markdown]
# ## 06-09 소프트맥스 회귀(Softmax Regression)

# %% [markdown]
# 앞서 로지스틱 회귀를 통해 2개의 선택지 중에서 1개를 고르는 이진 분류(Binary Classification)를 풀어봤습니다. 이번에는 3개 이상의 선택지 중에서 1개를 고르는 다중 클래스 분류 문제를 위한 소프트맥스 회귀(Softmax Regression)에 대해서 배웁니다.

# %% [markdown]
# ### 다중 클래스 분류(Multi-class Classification)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 소프트맥스 함수(Softmax function)

# %% [markdown]
# 1. 소프트맥스 함수의 이해

# %% [markdown]
# 분류하고자 하는 클래스가 k개일 때, k차원의 벡터를 입력받아서 모든 벡터 원소의 값을 0과 1사이의 값으로 값을 변경하여 다시 k차원의 벡터를 반환한다는 내용입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 그림을 통한 이해

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 원-핫 벡터의 무작위성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 비용 함수(Cost function)

# %% [markdown]
# 이진 분류에서의 크로스 엔트로피 함수와 동일하게 크로스 엔트로피 함수를 사용합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 인공 신경망 다이어그램

# %% [markdown]
# ![image.png](attachment:image.png)
