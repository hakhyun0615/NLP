# %% [markdown]
# ## 06-03 선형 회귀(Linear Regression)

# %% [markdown]
# 1. 단순 선형 회귀 분석(Simple Linear Regression Analysis)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 다중 선형 회귀 분석(Multiple Linear Regression Analysis)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 가설(Hypothesis) 세우기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 비용 함수(Cost function) : 평균 제곱 오차(MSE)

# %% [markdown]
# 실제값과 예측값에 대한 오차를 나타내는 손실 함수(ex.MSE)를 최소화하는 w와 b(파라미터)를 찾는 것이 머신러닝, 딥 러닝입니다. 이 때 사용되는 알고리즘이 옵티마이저라 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 옵티마이저(Optimizer) : 경사하강법(Gradient Descent)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
