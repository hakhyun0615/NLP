# %% [markdown]
# # 15-02 바다나우 어텐션(Bahdanau Attention)

# %% [markdown]
# 바다나우 어텐션 함수의 입, 출력은 다음과 같의 정의
#
# Attention(Q, K, V) = Attention Value
# - t = 어텐션 메커니즘이 수행되는 디코더 셀의 현재 시점을 의미.
# - Q = Query : t-1 시점의 디코더 셀에서의 은닉 상태
# - K = Keys : 모든 시점의 인코더 셀의 은닉 상태들
# - V = Values : 모든 시점의 인코더 셀의 은닉 상태들

# %% [markdown]
# ### 어텐션 스코어(Attention Score)를 구한다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 소프트맥스(softmax) 함수를 통해 어텐션 분포(Attention Distribution) 구하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 각 인코더의 어텐션 가중치와 은닉 상태를 가중합하여 어텐션 값(Attention Value) 구하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 컨텍스트 벡터로부터 st 구하기

# %% [markdown]
# ![image.png](attachment:image.png)
