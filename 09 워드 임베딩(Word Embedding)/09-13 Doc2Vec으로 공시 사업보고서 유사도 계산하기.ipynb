# %% [markdown]
# # 09-13 Doc2Vec으로 공시 사업보고서 유사도 계산하기

# %% [markdown]
# Word2Vec: 단어를 임베딩하는 워드 임베딩 알고리즘
# Doc2Vec: Word2Vec을 변형하여 문서의 임베딩을 얻을 수 있도록 한 알고리즘

# %% [markdown]
# ## 공시 사업 보고서 로드 및 전처리

# %% [markdown]
# 각 회사의 사업보고서를 Doc2Vec을 통해서 학습시키고, 특정 회사와 사업 보고서가 유사한 회사들을 찾아보겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## Doc2Vec 학습 및 테스트

# %% [markdown]
# ![image.png](attachment:image.png)
