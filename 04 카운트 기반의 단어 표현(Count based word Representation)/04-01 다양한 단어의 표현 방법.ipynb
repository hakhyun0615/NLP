# %% [markdown]
# ## 04-01 다양한 단어의 표현 방법

# %% [markdown]
# ### 단어의 표현 방법

# %% [markdown]
# 1. 국소 표현(Local Representation)/이산 표현(Discrete Representation) 방법: 해당 단어 그 자체만 보고, 특정값을 맵핑하여 단어를 표현하는 방법

# %% [markdown]
# 2. 분산 표현(Distributed Representation)/연속 표현(Continuous Represnetation) 방법: 그 단어를 표현하고자 주변을 참고하여 단어를 표현하는 방법

# %% [markdown]
# ### 단어 표현의 카테고리화

# %% [markdown]
# ![image.png](attachment:image.png)
