# %% [markdown]
# ## 08-02 장단기 메모리(Long Short-Term Memory, LSTM)

# %% [markdown]
# ### 바닐라 RNN(기본 RNN)의 한계: 장기 의존성 문제(the problem of Long-Term Dependencies)

# %% [markdown]
# -  짧은 시퀀스(sequence)에 대해서만 효과
# - 시점(time step)이 길어질 수록 앞의 정보가 뒤로 충분히 전달되지 못하는 현상이 발생(첫번째 입력값인 x1의 정보량을 짙은 남색으로 표현했을 때, 색이 점차 얕아지는 것으로 시점이 지날수록 x1의 정보량이 손실되어가는 과정을 표현하였습니다. 뒤로 갈수록 x1의 정보량은 손실되고, 시점이 충분히 긴 상황에서는 x1의 전체 정보에 대한 영향력은 거의 의미가 없을 수도 있습니다)

# %% [markdown]
# ### 바닐라 RNN 내부 열어보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### LSTM(Long Short-Term Memory)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 입력 게이트

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 삭제 게이트

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 셀 상태

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. 출력 게이트와 은닉 상태

# %% [markdown]
# ![image.png](attachment:image.png)
