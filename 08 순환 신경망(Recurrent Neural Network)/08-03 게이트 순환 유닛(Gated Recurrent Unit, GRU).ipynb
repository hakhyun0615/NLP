# %% [markdown]
# ## 08-03 게이트 순환 유닛(Gated Recurrent Unit, GRU)

# %% [markdown]
# GRU는 성능은 LSTM과 유사하면서 복잡했던 LSTM의 구조를 간단화 시켰습니다.

# %% [markdown]
# ### GRU(Gated Recurrent Unit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 케라스에서의 GRU(Gated Recurrent Unit)

# %% [markdown]
# 케라스에서는 역시 GRU에 대한 구현을 지원합니다. 사용 방법은 SimpleRNN이나 LSTM과 같습니다.

# %%
model.add(GRU(hidden_size, input_shape=(timesteps, input_dim)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.add(GRU(hidden_size, input_shape=(timesteps, input_dim)))
#
# NameError: name 'model' is not defined
